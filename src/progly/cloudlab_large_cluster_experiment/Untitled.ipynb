# %%
# %matplotlib inline
import pandas as pd
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels
import numpy as np
from  matplotlib.ticker import FuncFormatter
import glob

# %%
sns.set(color_codes=True)
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 1.5})
sns.reset_orig()

# %%
df = pd.read_csv("./1osds.dstat-client0.log", index_col=False, skiprows=6)
df["node"] = "client"
df["epoch"] = (df["epoch"] - min(df["epoch"])).astype(int)

tmp = pd.read_csv("./1osds.dstat-osd0.log", index_col=False, skiprows=6)
tmp["node"] = "osd0"
tmp["epoch"] = (tmp["epoch"] - min(tmp["epoch"])).astype(int)
df = pd.concat([df, tmp])

ax = df[df.node == "client"].plot.scatter(x='epoch', y='usr', figsize=(20, 5), s=1)
ax = df[df.node == "osd0"].plot.scatter(x='epoch', y='usr', figsize=(20, 5), s=1)
